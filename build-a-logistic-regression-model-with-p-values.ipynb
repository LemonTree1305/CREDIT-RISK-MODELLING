# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading the Data and Selecting the Features

# %% [markdown]
# ### Import Data

# %%
loan_data_inputs_train = pd.read_csv('loan_data_inputs_train.csv', index_col = 0)
loan_data_targets_train = pd.read_csv('loan_data_targets_train.csv', index_col = 0)
loan_data_inputs_test = pd.read_csv('loan_data_inputs_test.csv', index_col = 0)
loan_data_targets_test = pd.read_csv('loan_data_targets_test.csv', index_col = 0)

# %% [markdown]
# ### Explore Data

# %%
loan_data_inputs_train.head()
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 427211  12796369   14818505      24000        24000          24000.0
# 206088   1439740    1691948      10000        10000          10000.0
# 136020   5214749    6556909      20425        20425          20425.0
# 412305  13827698   15890016      17200        17200          17200.0
# 36159     422455     496525       8400         8400           7450.0
#
#               term  int_rate  installment grade sub_grade  ... dti:21.7-22.4  \
# 427211   36 months      8.90       762.08     A        A5  ...             1
# 206088   36 months     14.33       343.39     C        C1  ...             0
# 136020   36 months      8.90       648.56     A        A5  ...             0
# 412305   36 months     16.59       609.73     D        D1  ...             0
# 36159    36 months     12.84       282.40     C        C2  ...             0
#
#        dti:22.4-35 dti:>35  mths_since_last_record:Missing  \
# 427211           0       0                               1
# 206088           0       0                               1
# 136020           0       0                               1
# 412305           0       0                               1
# 36159            1       0                               1
#
#        mths_since_last_record:0-2 mths_since_last_record:3-20  \
# 427211                          0                           0
# 206088                          0                           0
# 136020                          0                           0
# 412305                          0                           0
# 36159                           0                           0
#
#        mths_since_last_record:21-31 mths_since_last_record:32-80  \
# 427211                            0                            0
# 206088                            0                            0
# 136020                            0                            0
# 412305                            0                            0
# 36159                             0                            0
#
#        mths_since_last_record:81-86 mths_since_last_record:>=86
# 427211                            0                           0
# 206088                            0                           0
# 136020                            0                           0
# 412305                            0                           0
# 36159                             0                           0
#
# [5 rows x 323 columns]

# %%
loan_data_targets_train.head()
# Out:
#         good_bad
# 427211         1
# 206088         1
# 136020         1
# 412305         0
# 36159          0

# %%
loan_data_inputs_train.shape
# Out:
# (373028, 323)

# %%
loan_data_targets_train.shape
# Out:
# (373028, 1)

# %%
loan_data_inputs_test.shape
# Out:
# (93257, 323)

# %%
loan_data_targets_test.shape
# Out:
# (93257, 1)

# %% [markdown]
# ### Selecting the Features

# %%
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'delinq_2yrs:0',
'delinq_2yrs:1-3',
'delinq_2yrs:>=4',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'open_acc:0',
'open_acc:1-3',
'open_acc:4-12',
'open_acc:13-17',
'open_acc:18-22',
'open_acc:23-25',
'open_acc:26-30',
'open_acc:>=31',
'pub_rec:0-2',
'pub_rec:3-4',
'pub_rec:>=5',
'total_acc:<=27',
'total_acc:28-51',
'total_acc:>=52',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'total_rev_hi_lim:<=5K',
'total_rev_hi_lim:5K-10K',
'total_rev_hi_lim:10K-20K',
'total_rev_hi_lim:20K-30K',
'total_rev_hi_lim:30K-40K',
'total_rev_hi_lim:40K-55K',
'total_rev_hi_lim:55K-95K',
'total_rev_hi_lim:>95K',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>=86']]

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'delinq_2yrs:>=4',
'inq_last_6mths:>6',
'open_acc:0',
'pub_rec:0-2',
'total_acc:<=27',
'acc_now_delinq:0',
'total_rev_hi_lim:<=5K',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 427211              0  ...                               1
# 206088              0  ...                               0
# 136020              0  ...                               0
# 412305              0  ...                               0
# 36159               0  ...                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 427211                            0                             0
# 206088                            0                             0
# 136020                            0                             0
# 412305                            0                             0
# 36159                             0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:>=86
# 427211                            0
# 206088                            0
# 136020                            0
# 412305                            0
# 36159                             0
#
# [5 rows x 104 columns]

# %% [markdown]
# # PD Model Estimation

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
reg = LogisticRegression()

# %%
pd.options.display.max_rows = None

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Out:
# C:\Users\trang\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\trang\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
reg.intercept_
# Out:
# array([-1.2796701])

# %%
reg.coef_
# Out:
# array([[ 1.160146  ,  0.90666853,  0.70835396,  0.51714283,  0.33333754,
#          0.14188375,  0.09302835,  0.10632758,  0.03031379,  0.05641359,
#          0.05675652,  0.05996761,  0.0762691 ,  0.13357841,  0.0983493 ,
#          0.18231891,  0.23325531,  0.22134936,  0.26045289,  0.31840488,
#          0.51820227,  0.08786899, -0.01042712,  0.30692012,  0.20291642,
#          0.2146905 ,  0.26954566,  0.0534953 ,  0.07696028,  0.10068689,
#          0.12670556,  0.09201534,  0.06142539,  0.12402117,  1.08266057,
#          0.88219483,  0.78254688,  0.57920473,  0.41740968,  0.17129414,
#         -0.06496055,  0.84961613,  0.53719384,  0.28866162,  0.10149454,
#          0.0575427 ,  0.04042075,  0.08194336,  0.12239362,  0.12951409,
#          0.07068399,  0.03392132,  0.65449627,  0.51120193,  0.30137269,
#         -0.00163585, -0.10089663, -0.12756445, -0.14296189, -0.14597419,
#         -0.10922058, -0.20036273,  0.12071867,  0.17349043, -0.02161967,
#          0.02260352,  0.23198471,  0.03714685,  0.00533188,  0.00269587,
#          0.01749441,  0.0386427 ,  0.06064018,  0.20643892, -0.06298711,
#          0.00542536,  0.10329494,  0.17232076,  0.24767439,  0.32243229,
#          0.39985718,  0.41803053,  0.49604263,  0.58419369,  0.51520537,
#          0.20375861,  0.33575438,  0.36185472,  0.30297653,  0.22664638,
#          0.12895451,  0.1182999 ,  0.0846796 ,  0.04449184,  0.10608076,
#          0.16887758,  0.18416569,  0.13666397,  0.23303497,  0.33270133,
#          0.25976708,  0.41795213,  0.06663222,  0.14049329]])

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                             Feature name  Coefficients
# 0                              Intercept     -1.279670
# 1                                grade:A      1.160146
# 2                                grade:B      0.906669
# 3                                grade:C      0.708354
# 4                                grade:D      0.517143
# 5                                grade:E      0.333338
# 6                                grade:F      0.141884
# 7                     home_ownership:OWN      0.093028
# 8                home_ownership:MORTGAGE      0.106328
# 9                       addr_state:NM_VA      0.030314
# 10                         addr_state:NY      0.056414
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.056757
# 12                         addr_state:CA      0.059968
# 13                addr_state:UT_KY_AZ_NJ      0.076269
# 14             addr_state:AR_MI_PA_OH_MN      0.133578
# 15             addr_state:RI_MA_DE_SD_IN      0.098349
# 16                   addr_state:GA_WA_OR      0.182319
# 17                      addr_state:WI_MT      0.233255
# 18                         addr_state:TX      0.221349
# 19                      addr_state:IL_CT      0.260453
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.318405
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.518202
# 22      verification_status:Not Verified      0.087869
# 23   verification_status:Source Verified     -0.010427
# 24                   purpose:credit_card      0.306920
# 25            purpose:debt_consolidation      0.202916
# 26            purpose:oth__med__vacation      0.214690
# 27   purpose:major_purch__car__home_impr      0.269546
# 28                 initial_list_status:w      0.053495
# 29                               term:36      0.076960
# 30                          emp_length:1      0.100687
# 31                        emp_length:2-4      0.126706
# 32                        emp_length:5-6      0.092015
# 33                        emp_length:7-9      0.061425
# 34                         emp_length:10      0.124021
# 35                mths_since_issue_d:<38      1.082661
# 36              mths_since_issue_d:38-39      0.882195
# 37              mths_since_issue_d:40-41      0.782547
# 38              mths_since_issue_d:42-48      0.579205
# 39              mths_since_issue_d:49-52      0.417410
# 40              mths_since_issue_d:53-64      0.171294
# 41              mths_since_issue_d:65-84     -0.064961
# 42                       int_rate:<9.548      0.849616
# 43                 int_rate:9.548-12.025      0.537194
# 44                 int_rate:12.025-15.74      0.288662
# 45                 int_rate:15.74-20.281      0.101495
# 46   mths_since_earliest_cr_line:141-164      0.057543
# 47   mths_since_earliest_cr_line:165-247      0.040421
# 48   mths_since_earliest_cr_line:248-270      0.081943
# 49   mths_since_earliest_cr_line:271-352      0.122394
# 50      mths_since_earliest_cr_line:>352      0.129514
# 51                         delinq_2yrs:0      0.070684
# 52                       delinq_2yrs:1-3      0.033921
# 53                      inq_last_6mths:0      0.654496
# 54                    inq_last_6mths:1-2      0.511202
# 55                    inq_last_6mths:3-6      0.301373
# 56                          open_acc:1-3     -0.001636
# 57                         open_acc:4-12     -0.100897
# 58                        open_acc:13-17     -0.127564
# 59                        open_acc:18-22     -0.142962
# 60                        open_acc:23-25     -0.145974
# 61                        open_acc:26-30     -0.109221
# 62                         open_acc:>=31     -0.200363
# 63                           pub_rec:3-4      0.120719
# 64                           pub_rec:>=5      0.173490
# 65                       total_acc:28-51     -0.021620
# 66                        total_acc:>=52      0.022604
# 67                    acc_now_delinq:>=1      0.231985
# 68               total_rev_hi_lim:5K-10K      0.037147
# 69              total_rev_hi_lim:10K-20K      0.005332
# 70              total_rev_hi_lim:20K-30K      0.002696
# 71              total_rev_hi_lim:30K-40K      0.017494
# 72              total_rev_hi_lim:40K-55K      0.038643
# 73              total_rev_hi_lim:55K-95K      0.060640
# 74                 total_rev_hi_lim:>95K      0.206439
# 75                    annual_inc:20K-30K     -0.062987
# 76                    annual_inc:30K-40K      0.005425
# 77                    annual_inc:40K-50K      0.103295
# 78                    annual_inc:50K-60K      0.172321
# 79                    annual_inc:60K-70K      0.247674
# 80                    annual_inc:70K-80K      0.322432
# 81                    annual_inc:80K-90K      0.399857
# 82                   annual_inc:90K-100K      0.418031
# 83                  annual_inc:100K-120K      0.496043
# 84                  annual_inc:120K-140K      0.584194
# 85                      annual_inc:>140K      0.515205
# 86                             dti:<=1.4      0.203759
# 87                           dti:1.4-3.5      0.335754
# 88                           dti:3.5-7.7      0.361855
# 89                          dti:7.7-10.5      0.302977
# 90                         dti:10.5-16.1      0.226646
# 91                         dti:16.1-20.3      0.128955
# 92                         dti:20.3-21.7      0.118300
# 93                         dti:21.7-22.4      0.084680
# 94                           dti:22.4-35      0.044492
# 95        mths_since_last_delinq:Missing      0.106081
# 96           mths_since_last_delinq:4-30      0.168878
# 97          mths_since_last_delinq:31-56      0.184166
# 98           mths_since_last_delinq:>=57      0.136664
# 99        mths_since_last_record:Missing      0.233035
# 100          mths_since_last_record:3-20      0.332701
# 101         mths_since_last_record:21-31      0.259767
# 102         mths_since_last_record:32-80      0.417952
# 103         mths_since_last_record:81-86      0.066632
# 104          mths_since_last_record:>=86      0.140493

# %%
print (summary_table.head(10))
# Out:
#               Feature name  Coefficients
# 0                Intercept     -1.279670
# 1                  grade:A      1.160146
# 2                  grade:B      0.906669
# 3                  grade:C      0.708354
# 4                  grade:D      0.517143
# 5                  grade:E      0.333338
# 6                  grade:F      0.141884
# 7       home_ownership:OWN      0.093028
# 8  home_ownership:MORTGAGE      0.106328
# 9         addr_state:NM_VA      0.030314

# %% [markdown]
# ## Build a Logistic Regression Model with P-Values

# %%
from sklearn import linear_model
import scipy.stats as stat

class LogisticRegression_with_p_values:
    
    def __init__(self,*args,**kwargs):
        self.model = linear_model.LogisticRegression(*args,**kwargs)

    def fit(self,X,y):
        self.model.fit(X,y)
        denom = (2.0 * (1.0 + np.cosh(self.model.decision_function(X))))
        denom = np.tile(denom,(X.shape[1],1)).T
        F_ij = np.dot((X / denom).T,X)
        Cramer_Rao = np.linalg.inv(F_ij)
        sigma_estimates = np.sqrt(np.diagonal(Cramer_Rao))
        z_scores = self.model.coef_[0] / sigma_estimates
        p_values = [stat.norm.sf(abs(x)) * 2 for x in z_scores]
        self.coef_ = self.model.coef_
        self.intercept_ = self.model.intercept_
        self.p_values = p_values

# %%
reg = LogisticRegression_with_p_values()

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Out:
# C:\Users\trang\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\trang\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                             Feature name  Coefficients
# 0                              Intercept     -1.279670
# 1                                grade:A      1.160146
# 2                                grade:B      0.906669
# 3                                grade:C      0.708354
# 4                                grade:D      0.517143
# 5                                grade:E      0.333338
# 6                                grade:F      0.141884
# 7                     home_ownership:OWN      0.093028
# 8                home_ownership:MORTGAGE      0.106328
# 9                       addr_state:NM_VA      0.030314
# 10                         addr_state:NY      0.056414
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.056757
# 12                         addr_state:CA      0.059968
# 13                addr_state:UT_KY_AZ_NJ      0.076269
# 14             addr_state:AR_MI_PA_OH_MN      0.133578
# 15             addr_state:RI_MA_DE_SD_IN      0.098349
# 16                   addr_state:GA_WA_OR      0.182319
# 17                      addr_state:WI_MT      0.233255
# 18                         addr_state:TX      0.221349
# 19                      addr_state:IL_CT      0.260453
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.318405
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.518202
# 22      verification_status:Not Verified      0.087869
# 23   verification_status:Source Verified     -0.010427
# 24                   purpose:credit_card      0.306920
# 25            purpose:debt_consolidation      0.202916
# 26            purpose:oth__med__vacation      0.214690
# 27   purpose:major_purch__car__home_impr      0.269546
# 28                 initial_list_status:w      0.053495
# 29                               term:36      0.076960
# 30                          emp_length:1      0.100687
# 31                        emp_length:2-4      0.126706
# 32                        emp_length:5-6      0.092015
# 33                        emp_length:7-9      0.061425
# 34                         emp_length:10      0.124021
# 35                mths_since_issue_d:<38      1.082661
# 36              mths_since_issue_d:38-39      0.882195
# 37              mths_since_issue_d:40-41      0.782547
# 38              mths_since_issue_d:42-48      0.579205
# 39              mths_since_issue_d:49-52      0.417410
# 40              mths_since_issue_d:53-64      0.171294
# 41              mths_since_issue_d:65-84     -0.064961
# 42                       int_rate:<9.548      0.849616
# 43                 int_rate:9.548-12.025      0.537194
# 44                 int_rate:12.025-15.74      0.288662
# 45                 int_rate:15.74-20.281      0.101495
# 46   mths_since_earliest_cr_line:141-164      0.057543
# 47   mths_since_earliest_cr_line:165-247      0.040421
# 48   mths_since_earliest_cr_line:248-270      0.081943
# 49   mths_since_earliest_cr_line:271-352      0.122394
# 50      mths_since_earliest_cr_line:>352      0.129514
# 51                         delinq_2yrs:0      0.070684
# 52                       delinq_2yrs:1-3      0.033921
# 53                      inq_last_6mths:0      0.654496
# 54                    inq_last_6mths:1-2      0.511202
# 55                    inq_last_6mths:3-6      0.301373
# 56                          open_acc:1-3     -0.001636
# 57                         open_acc:4-12     -0.100897
# 58                        open_acc:13-17     -0.127564
# 59                        open_acc:18-22     -0.142962
# 60                        open_acc:23-25     -0.145974
# 61                        open_acc:26-30     -0.109221
# 62                         open_acc:>=31     -0.200363
# 63                           pub_rec:3-4      0.120719
# 64                           pub_rec:>=5      0.173490
# 65                       total_acc:28-51     -0.021620
# 66                        total_acc:>=52      0.022604
# 67                    acc_now_delinq:>=1      0.231985
# 68               total_rev_hi_lim:5K-10K      0.037147
# 69              total_rev_hi_lim:10K-20K      0.005332
# 70              total_rev_hi_lim:20K-30K      0.002696
# 71              total_rev_hi_lim:30K-40K      0.017494
# 72              total_rev_hi_lim:40K-55K      0.038643
# 73              total_rev_hi_lim:55K-95K      0.060640
# 74                 total_rev_hi_lim:>95K      0.206439
# 75                    annual_inc:20K-30K     -0.062987
# 76                    annual_inc:30K-40K      0.005425
# 77                    annual_inc:40K-50K      0.103295
# 78                    annual_inc:50K-60K      0.172321
# 79                    annual_inc:60K-70K      0.247674
# 80                    annual_inc:70K-80K      0.322432
# 81                    annual_inc:80K-90K      0.399857
# 82                   annual_inc:90K-100K      0.418031
# 83                  annual_inc:100K-120K      0.496043
# 84                  annual_inc:120K-140K      0.584194
# 85                      annual_inc:>140K      0.515205
# 86                             dti:<=1.4      0.203759
# 87                           dti:1.4-3.5      0.335754
# 88                           dti:3.5-7.7      0.361855
# 89                          dti:7.7-10.5      0.302977
# 90                         dti:10.5-16.1      0.226646
# 91                         dti:16.1-20.3      0.128955
# 92                         dti:20.3-21.7      0.118300
# 93                         dti:21.7-22.4      0.084680
# 94                           dti:22.4-35      0.044492
# 95        mths_since_last_delinq:Missing      0.106081
# 96           mths_since_last_delinq:4-30      0.168878
# 97          mths_since_last_delinq:31-56      0.184166
# 98           mths_since_last_delinq:>=57      0.136664
# 99        mths_since_last_record:Missing      0.233035
# 100          mths_since_last_record:3-20      0.332701
# 101         mths_since_last_record:21-31      0.259767
# 102         mths_since_last_record:32-80      0.417952
# 103         mths_since_last_record:81-86      0.066632
# 104          mths_since_last_record:>=86      0.140493

# %%
p_values = reg.p_values

# %%
p_values = np.append(np.nan, np.array(p_values))

# %%
summary_table['p_values'] = p_values

# %%
summary_table
# Out:
#                             Feature name  Coefficients       p_values
# 0                              Intercept     -1.279670            NaN
# 1                                grade:A      1.160146   1.693359e-37
# 2                                grade:B      0.906669   8.292253e-50
# 3                                grade:C      0.708354   7.251884e-36
# 4                                grade:D      0.517143   7.100485e-22
# 5                                grade:E      0.333338   4.267484e-12
# 6                                grade:F      0.141884   4.675636e-03
# 7                     home_ownership:OWN      0.093028   4.074308e-06
# 8                home_ownership:MORTGAGE      0.106328   5.689572e-17
# 9                       addr_state:NM_VA      0.030314   3.441444e-01
# 10                         addr_state:NY      0.056414   2.027032e-02
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.056757   1.451574e-02
# 12                         addr_state:CA      0.059968   4.787122e-03
# 13                addr_state:UT_KY_AZ_NJ      0.076269   2.255736e-03
# 14             addr_state:AR_MI_PA_OH_MN      0.133578   3.374336e-09
# 15             addr_state:RI_MA_DE_SD_IN      0.098349   1.002006e-03
# 16                   addr_state:GA_WA_OR      0.182319   8.990299e-12
# 17                      addr_state:WI_MT      0.233255   9.201945e-07
# 18                         addr_state:TX      0.221349   1.850343e-17
# 19                      addr_state:IL_CT      0.260453   5.690932e-19
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.318405   6.391249e-25
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.518202   2.103333e-22
# 22      verification_status:Not Verified      0.087869   2.263786e-09
# 23   verification_status:Source Verified     -0.010427   4.390507e-01
# 24                   purpose:credit_card      0.306920   3.802912e-27
# 25            purpose:debt_consolidation      0.202916   8.762145e-15
# 26            purpose:oth__med__vacation      0.214690   6.282430e-12
# 27   purpose:major_purch__car__home_impr      0.269546   8.567105e-18
# 28                 initial_list_status:w      0.053495   4.179916e-05
# 29                               term:36      0.076960   5.754059e-08
# 30                          emp_length:1      0.100687   1.051377e-04
# 31                        emp_length:2-4      0.126706   1.982134e-11
# 32                        emp_length:5-6      0.092015   1.735043e-05
# 33                        emp_length:7-9      0.061425   3.156102e-03
# 34                         emp_length:10      0.124021   1.767955e-11
# 35                mths_since_issue_d:<38      1.082661  8.590135e-175
# 36              mths_since_issue_d:38-39      0.882195  9.631309e-145
# 37              mths_since_issue_d:40-41      0.782547  7.109651e-120
# 38              mths_since_issue_d:42-48      0.579205   8.189101e-84
# 39              mths_since_issue_d:49-52      0.417410   3.109955e-39
# 40              mths_since_issue_d:53-64      0.171294   1.125140e-08
# 41              mths_since_issue_d:65-84     -0.064961   2.607708e-02
# 42                       int_rate:<9.548      0.849616   5.674606e-29
# 43                 int_rate:9.548-12.025      0.537194   5.480816e-33
# 44                 int_rate:12.025-15.74      0.288662   5.492247e-15
# 45                 int_rate:15.74-20.281      0.101495   4.914750e-04
# 46   mths_since_earliest_cr_line:141-164      0.057543   2.122025e-02
# 47   mths_since_earliest_cr_line:165-247      0.040421   4.719906e-02
# 48   mths_since_earliest_cr_line:248-270      0.081943   2.072354e-03
# 49   mths_since_earliest_cr_line:271-352      0.122394   3.071035e-07
# 50      mths_since_earliest_cr_line:>352      0.129514   1.690188e-06
# 51                         delinq_2yrs:0      0.070684   2.154562e-01
# 52                       delinq_2yrs:1-3      0.033921   5.275688e-01
# 53                      inq_last_6mths:0      0.654496   1.240039e-08
# 54                    inq_last_6mths:1-2      0.511202   8.440150e-06
# 55                    inq_last_6mths:3-6      0.301373   8.940120e-03
# 56                          open_acc:1-3     -0.001636   9.920816e-01
# 57                         open_acc:4-12     -0.100897   5.307440e-01
# 58                        open_acc:13-17     -0.127564   4.289446e-01
# 59                        open_acc:18-22     -0.142962   3.782819e-01
# 60                        open_acc:23-25     -0.145974   3.818033e-01
# 61                        open_acc:26-30     -0.109221   5.259264e-01
# 62                         open_acc:>=31     -0.200363   2.818282e-01
# 63                           pub_rec:3-4      0.120719   2.028514e-01
# 64                           pub_rec:>=5      0.173490   3.679782e-01
# 65                       total_acc:28-51     -0.021620   1.280396e-01
# 66                        total_acc:>=52      0.022604   5.693609e-01
# 67                    acc_now_delinq:>=1      0.231985   2.880199e-02
# 68               total_rev_hi_lim:5K-10K      0.037147   1.318925e-01
# 69              total_rev_hi_lim:10K-20K      0.005332   8.234855e-01
# 70              total_rev_hi_lim:20K-30K      0.002696   9.182431e-01
# 71              total_rev_hi_lim:30K-40K      0.017494   5.528612e-01
# 72              total_rev_hi_lim:40K-55K      0.038643   2.299064e-01
# 73              total_rev_hi_lim:55K-95K      0.060640   9.249207e-02
# 74                 total_rev_hi_lim:>95K      0.206439   2.624324e-04
# 75                    annual_inc:20K-30K     -0.062987   1.424499e-01
# 76                    annual_inc:30K-40K      0.005425   8.958535e-01
# 77                    annual_inc:40K-50K      0.103295   1.278531e-02
# 78                    annual_inc:50K-60K      0.172321   4.214095e-05
# 79                    annual_inc:60K-70K      0.247674   9.016712e-09
# 80                    annual_inc:70K-80K      0.322432   2.337859e-13
# 81                    annual_inc:80K-90K      0.399857   2.632912e-18
# 82                   annual_inc:90K-100K      0.418031   1.210264e-18
# 83                  annual_inc:100K-120K      0.496043   6.875223e-26
# 84                  annual_inc:120K-140K      0.584194   6.937885e-28
# 85                      annual_inc:>140K      0.515205   2.751739e-25
# 86                             dti:<=1.4      0.203759   2.123525e-02
# 87                           dti:1.4-3.5      0.335754   7.297367e-06
# 88                           dti:3.5-7.7      0.361855   2.959926e-08
# 89                          dti:7.7-10.5      0.302977   2.824800e-06
# 90                         dti:10.5-16.1      0.226646   3.009838e-04
# 91                         dti:16.1-20.3      0.128955   3.962944e-02
# 92                         dti:20.3-21.7      0.118300   6.929894e-02
# 93                         dti:21.7-22.4      0.084680   2.193232e-01
# 94                           dti:22.4-35      0.044492   4.724333e-01
# 95        mths_since_last_delinq:Missing      0.106081   5.991160e-02
# 96           mths_since_last_delinq:4-30      0.168878   1.216799e-03
# 97          mths_since_last_delinq:31-56      0.184166   1.371835e-03
# 98           mths_since_last_delinq:>=57      0.136664   1.991376e-02
# 99        mths_since_last_record:Missing      0.233035   2.422940e-03
# 100          mths_since_last_record:3-20      0.332701   5.981109e-03
# 101         mths_since_last_record:21-31      0.259767   1.815808e-02
# 102         mths_since_last_record:32-80      0.417952   2.646925e-07
# 103         mths_since_last_record:81-86      0.066632   4.521266e-01
# 104          mths_since_last_record:>=86      0.140493   7.297986e-02

# %%
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>=86']]

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 427211              0  ...                               1
# 206088              0  ...                               0
# 136020              0  ...                               0
# 412305              0  ...                               0
# 36159               0  ...                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 427211                            0                             0
# 206088                            0                             0
# 136020                            0                             0
# 412305                            0                             0
# 36159                             0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:>=86
# 427211                            0
# 206088                            0
# 136020                            0
# 412305                            0
# 36159                             0
#
# [5 rows x 84 columns]

# %%
reg2 = LogisticRegression_with_p_values()
reg2.fit(inputs_train, loan_data_targets_train)
# Out:
# C:\Users\trang\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\trang\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg2.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg2.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                            Feature name  Coefficients
# 0                             Intercept     -1.285478
# 1                               grade:A      1.141219
# 2                               grade:B      0.885134
# 3                               grade:C      0.690067
# 4                               grade:D      0.502034
# 5                               grade:E      0.326603
# 6                               grade:F      0.136833
# 7                    home_ownership:OWN      0.091909
# 8               home_ownership:MORTGAGE      0.106068
# 9                      addr_state:NM_VA      0.028894
# 10                        addr_state:NY      0.051285
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.053486
# 12                        addr_state:CA      0.057933
# 13               addr_state:UT_KY_AZ_NJ      0.073062
# 14            addr_state:AR_MI_PA_OH_MN      0.130200
# 15            addr_state:RI_MA_DE_SD_IN      0.094414
# 16                  addr_state:GA_WA_OR      0.180150
# 17                     addr_state:WI_MT      0.223667
# 18                        addr_state:TX      0.216846
# 19                     addr_state:IL_CT      0.256028
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.314907
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.516382
# 22     verification_status:Not Verified      0.084616
# 23  verification_status:Source Verified     -0.010895
# 24                  purpose:credit_card      0.305107
# 25           purpose:debt_consolidation      0.201227
# 26           purpose:oth__med__vacation      0.217117
# 27  purpose:major_purch__car__home_impr      0.269177
# 28                initial_list_status:w      0.054367
# 29                              term:36      0.078434
# 30                         emp_length:1      0.100007
# 31                       emp_length:2-4      0.126244
# 32                       emp_length:5-6      0.091491
# 33                       emp_length:7-9      0.061723
# 34                        emp_length:10      0.125873
# 35               mths_since_issue_d:<38      1.091351
# 36             mths_since_issue_d:38-39      0.886866
# 37             mths_since_issue_d:40-41      0.786364
# 38             mths_since_issue_d:42-48      0.585583
# 39             mths_since_issue_d:49-52      0.424524
# 40             mths_since_issue_d:53-64      0.178538
# 41             mths_since_issue_d:65-84     -0.062583
# 42                      int_rate:<9.548      0.872003
# 43                int_rate:9.548-12.025      0.557210
# 44                int_rate:12.025-15.74      0.305648
# 45                int_rate:15.74-20.281      0.112880
# 46  mths_since_earliest_cr_line:141-164      0.054014
# 47  mths_since_earliest_cr_line:165-247      0.035973
# 48  mths_since_earliest_cr_line:248-270      0.077428
# 49  mths_since_earliest_cr_line:271-352      0.120513
# 50     mths_since_earliest_cr_line:>352      0.128505
# 51                     inq_last_6mths:0      0.655859
# 52                   inq_last_6mths:1-2      0.509582
# 53                   inq_last_6mths:3-6      0.299320
# 54                   acc_now_delinq:>=1      0.201684
# 55                   annual_inc:20K-30K     -0.079788
# 56                   annual_inc:30K-40K     -0.017641
# 57                   annual_inc:40K-50K      0.077229
# 58                   annual_inc:50K-60K      0.144130
# 59                   annual_inc:60K-70K      0.219688
# 60                   annual_inc:70K-80K      0.293108
# 61                   annual_inc:80K-90K      0.368871
# 62                  annual_inc:90K-100K      0.389257
# 63                 annual_inc:100K-120K      0.466807
# 64                 annual_inc:120K-140K      0.557062
# 65                     annual_inc:>140K      0.494627
# 66                            dti:<=1.4      0.242920
# 67                          dti:1.4-3.5      0.362306
# 68                          dti:3.5-7.7      0.377527
# 69                         dti:7.7-10.5      0.313163
# 70                        dti:10.5-16.1      0.233756
# 71                        dti:16.1-20.3      0.132411
# 72                        dti:20.3-21.7      0.120198
# 73                        dti:21.7-22.4      0.084503
# 74                          dti:22.4-35      0.043014
# 75       mths_since_last_delinq:Missing      0.133271
# 76          mths_since_last_delinq:4-30      0.159556
# 77         mths_since_last_delinq:31-56      0.205905
# 78          mths_since_last_delinq:>=57      0.158590
# 79       mths_since_last_record:Missing      0.214644
# 80          mths_since_last_record:3-20      0.330379
# 81         mths_since_last_record:21-31      0.231732
# 82         mths_since_last_record:32-80      0.397450
# 83         mths_since_last_record:81-86      0.044308
# 84          mths_since_last_record:>=86      0.119907

# %%
p_values = reg2.p_values
p_values = np.append(np.nan, np.array(p_values))
summary_table['p_values'] = p_values
summary_table
# Out:
#                            Feature name  Coefficients       p_values
# 0                             Intercept     -1.285478            NaN
# 1                               grade:A      1.141219   1.832479e-36
# 2                               grade:B      0.885134   7.377015e-48
# 3                               grade:C      0.690067   1.779222e-34
# 4                               grade:D      0.502034   4.885351e-21
# 5                               grade:E      0.326603   4.525676e-12
# 6                               grade:F      0.136833   5.268097e-03
# 7                    home_ownership:OWN      0.091909   5.027105e-06
# 8               home_ownership:MORTGAGE      0.106068   4.970415e-17
# 9                      addr_state:NM_VA      0.028894   3.668069e-01
# 10                        addr_state:NY      0.051285   3.432814e-02
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.053486   2.094863e-02
# 12                        addr_state:CA      0.057933   6.315747e-03
# 13               addr_state:UT_KY_AZ_NJ      0.073062   3.377269e-03
# 14            addr_state:AR_MI_PA_OH_MN      0.130200   7.607200e-09
# 15            addr_state:RI_MA_DE_SD_IN      0.094414   1.557719e-03
# 16                  addr_state:GA_WA_OR      0.180150   1.456243e-11
# 17                     addr_state:WI_MT      0.223667   2.363769e-06
# 18                        addr_state:TX      0.216846   7.251883e-17
# 19                     addr_state:IL_CT      0.256028   1.883492e-18
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.314907   1.796471e-24
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.516382   2.848207e-22
# 22     verification_status:Not Verified      0.084616   6.754769e-09
# 23  verification_status:Source Verified     -0.010895   4.172184e-01
# 24                  purpose:credit_card      0.305107   3.295197e-27
# 25           purpose:debt_consolidation      0.201227   9.203902e-15
# 26           purpose:oth__med__vacation      0.217117   2.826040e-12
# 27  purpose:major_purch__car__home_impr      0.269177   6.116744e-18
# 28                initial_list_status:w      0.054367   3.119193e-05
# 29                              term:36      0.078434   2.001923e-08
# 30                         emp_length:1      0.100007   1.150311e-04
# 31                       emp_length:2-4      0.126244   2.226323e-11
# 32                       emp_length:5-6      0.091491   1.906962e-05
# 33                       emp_length:7-9      0.061723   2.998198e-03
# 34                        emp_length:10      0.125873   8.539574e-12
# 35               mths_since_issue_d:<38      1.091351  4.315891e-185
# 36             mths_since_issue_d:38-39      0.886866  5.659053e-154
# 37             mths_since_issue_d:40-41      0.786364  6.285730e-128
# 38             mths_since_issue_d:42-48      0.585583   2.418108e-91
# 39             mths_since_issue_d:49-52      0.424524   6.741557e-43
# 40             mths_since_issue_d:53-64      0.178538   8.020366e-10
# 41             mths_since_issue_d:65-84     -0.062583   3.141603e-02
# 42                      int_rate:<9.548      0.872003   1.337665e-30
# 43                int_rate:9.548-12.025      0.557210   8.542252e-36
# 44                int_rate:12.025-15.74      0.305648   8.050807e-17
# 45                int_rate:15.74-20.281      0.112880   9.750556e-05
# 46  mths_since_earliest_cr_line:141-164      0.054014   2.990632e-02
# 47  mths_since_earliest_cr_line:165-247      0.035973   7.321086e-02
# 48  mths_since_earliest_cr_line:248-270      0.077428   3.161933e-03
# 49  mths_since_earliest_cr_line:271-352      0.120513   2.668541e-07
# 50     mths_since_earliest_cr_line:>352      0.128505   1.255700e-06
# 51                     inq_last_6mths:0      0.655859   4.128854e-14
# 52                   inq_last_6mths:1-2      0.509582   4.148736e-09
# 53                   inq_last_6mths:3-6      0.299320   6.040701e-04
# 54                   acc_now_delinq:>=1      0.201684   5.562689e-02
# 55                   annual_inc:20K-30K     -0.079788   5.803009e-02
# 56                   annual_inc:30K-40K     -0.017641   6.627442e-01
# 57                   annual_inc:40K-50K      0.077229   5.586832e-02
# 58                   annual_inc:50K-60K      0.144130   4.268370e-04
# 59                   annual_inc:60K-70K      0.219688   1.517945e-07
# 60                   annual_inc:70K-80K      0.293108   6.524082e-12
# 61                   annual_inc:80K-90K      0.368871   1.048081e-16
# 62                  annual_inc:90K-100K      0.389257   2.742331e-17
# 63                 annual_inc:100K-120K      0.466807   1.467434e-24
# 64                 annual_inc:120K-140K      0.557062   6.910761e-27
# 65                     annual_inc:>140K      0.494627   2.417717e-25
# 66                            dti:<=1.4      0.242920   3.570055e-03
# 67                          dti:1.4-3.5      0.362306   2.252742e-07
# 68                          dti:3.5-7.7      0.377527   3.749525e-10
# 69                         dti:7.7-10.5      0.313163   1.709751e-07
# 70                        dti:10.5-16.1      0.233756   5.384542e-05
# 71                        dti:16.1-20.3      0.132411   2.237280e-02
# 72                        dti:20.3-21.7      0.120198   4.760739e-02
# 73                        dti:21.7-22.4      0.084503   1.918822e-01
# 74                          dti:22.4-35      0.043014   4.528725e-01
# 75       mths_since_last_delinq:Missing      0.133271   9.056640e-03
# 76          mths_since_last_delinq:4-30      0.159556   2.021833e-03
# 77         mths_since_last_delinq:31-56      0.205905   8.412262e-05
# 78          mths_since_last_delinq:>=57      0.158590   3.120493e-03
# 79       mths_since_last_record:Missing      0.214644   3.348475e-03
# 80          mths_since_last_record:3-20      0.330379   4.894670e-03
# 81         mths_since_last_record:21-31      0.231732   2.944955e-02
# 82         mths_since_last_record:32-80      0.397450   2.960680e-07
# 83         mths_since_last_record:81-86      0.044308   6.076607e-01
# 84          mths_since_last_record:>=86      0.119907   1.094645e-01

# %%
import pickle

# %%
pickle.dump(reg2, open('pd_model.sav', 'wb'))
